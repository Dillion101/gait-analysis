# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import numpy as np
import os

# %%
import pandas as pd
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

def load_and_preprocess_data(csv_path, image_base_path, angles_to_process=None):
    # Load the metadata CSV
    df = pd.read_csv(csv_path)
    angle_groups = df.groupby('cam_angle')
    
    # If angles_to_process is not specified, process all angles
    if angles_to_process is None:
        angles_to_process = angle_groups.groups.keys()
    else:
        angles_to_process = [angles_to_process] if isinstance(angles_to_process, (int, float)) else angles_to_process
    
    X_all, y_all = [], []
    
    # Iterate through each angle and process
    for angle in angles_to_process:
        if angle not in angle_groups.groups:
            print(f"Angle {angle} not found in the dataset. Skipping.")
            continue
        print(f"Processing angle: {angle}")
        group = angle_groups.get_group(angle)
        
        for _, row in group.iterrows():
            image_path = os.path.join(image_base_path, row['image_filename'])
            try:
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    img = cv2.resize(img, (240, 240))
                    img = img.astype('float32') / 255.0  # Normalize to [0, 1]
                    X_all.append(img)
                    y_all.append(row['label'])
                else:
                    print(f"Failed to load image: {image_path}")
            except Exception as e:
                print(f"Error processing image {image_path}: {str(e)}")
    
    if not X_all:
        raise ValueError("No valid images found in the dataset.")
    
    X_all = np.array(X_all)
    y_all = np.array(y_all)
    
    # Use LabelEncoder to ensure labels are zero-indexed
    label_encoder = LabelEncoder()
    y_all = label_encoder.fit_transform(y_all)
    
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=42)
    
    # Reshape the data to match the CIFAR-10 format
    X_train = X_train.reshape(-1, 240, 240, 1)
    X_test = X_test.reshape(-1, 240, 240, 1)
    
    # Get the number of unique classes
    num_classes = len(label_encoder.classes_)
    
    return (X_train, y_train), (X_test, y_test), num_classes

def load_data():
    # Define the paths
    csv_path = '/kaggle/input/dewgi-dataset/dewgi_metadata.csv'
    image_base_path = '/kaggle/input/dewgi-dataset/dewgi_images'
    
    # Specify the angles to process
    angles_to_process = [0, 18, 36, 54, 72, 90, 108, 126, 144, 162, 180]
    
    # Load and preprocess the data
    return load_and_preprocess_data(csv_path, image_base_path, angles_to_process)

# Usage example:
(X_train, y_train), (X_test, y_test), num_classes = load_data()

# Print summary of the loaded data
print("\nSummary of loaded data:")
print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")
print(f"Image shape: {X_train.shape[1:]}")
print(f"Number of classes: {num_classes}")

# Data Preprocessing
subtract_pixel_mean = True

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(X_train, axis=0)
    X_train -= x_train_mean
    X_test -= x_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes) 
y_test = keras.utils.to_categorical(y_test, num_classes)

# Print shapes after preprocessing
print("\nAfter preprocessing:")
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# Processing angle: 0
# Processing angle: 18
# Processing angle: 36
# Processing angle: 54
# Processing angle: 72
# Processing angle: 90
# Processing angle: 108
# Processing angle: 126
# Processing angle: 144
# Processing angle: 162
# Processing angle: 180
#
# Summary of loaded data:
# Training samples: 6524
# Testing samples: 1631
# Image shape: (240, 240, 1)
# Number of classes: 124
#
# After preprocessing:
# X_train shape: (6524, 240, 240, 1)
# 6524 train samples
# 1631 test samples
# y_train shape: (6524, 124)

# %%
# Setting LR for different number of Epochs 
def lr_schedule(epoch): 
	lr = 1e-3
	if epoch > 180: 
		lr *= 0.5e-3
	elif epoch > 160: 
		lr *= 1e-3
	elif epoch > 120: 
		lr *= 1e-2
	elif epoch > 80: 
		lr *= 1e-1
	print('Learning rate: ', lr) 
	return lr

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation
from tensorflow.keras.regularizers import l2

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    Args:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or bn-activation-conv (False)

    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Activation, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def resnet_v1(input_shape, depth, num_classes=10):
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])')
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Activation, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def resnet_v1(input_shape, depth, num_classes=124):  # Changed default to 124
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])')
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Create the model
input_shape = X_train.shape[1:]  # Assuming x_train is your input data
depth = 20  # or whatever depth you're using
model = resnet_v1(input_shape=input_shape, depth=depth, num_classes=124)

# Print model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 240, 240,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 240, 240,  │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 240, 240,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_1[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 240, 240,  │          0 │ activation[0][0], │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 240, 240,  │          0 │ add[0][0]         │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_2[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_3[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 240, 240,  │          0 │ activation_2[0][… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 240, 240,  │          0 │ add_1[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_4[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_5[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 240, 240,  │          0 │ activation_4[0][… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 240, 240,  │          0 │ add_2[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 120, 120,  │      4,640 │ activation_6[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 120, 120,  │      9,248 │ activation_7[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 120, 120,  │        544 │ activation_6[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 120, 120,  │          0 │ conv2d_9[0][0],   │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 120, 120,  │          0 │ add_3[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_8[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_9[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 120, 120,  │          0 │ activation_8[0][… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 120, 120,  │          0 │ add_4[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_10[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_11[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 120, 120,  │          0 │ activation_10[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 120, 120,  │          0 │ add_5[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 60, 60,    │     18,496 │ activation_12[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_13[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 60, 60,    │      2,112 │ activation_12[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 60, 60,    │          0 │ conv2d_16[0][0],  │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 60, 60,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_14[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_15[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 60, 60,    │          0 │ activation_14[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 60, 60,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_17[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 60, 60,    │          0 │ activation_16[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 60, 60,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 7, 7, 64)  │          0 │ activation_18[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3136)      │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 124)       │    388,988 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 662,492 (2.53 MB)
#  Trainable params: 661,116 (2.52 MB)
#  Non-trainable params: 1,376 (5.38 KB)

# %%
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau

# Learning rate schedule
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Set up model name and save directory
version = 1  # Assuming you're using version 1
depth = 20  # Assuming you're using depth 20
model_type = f'ResNet{depth}v{version}'
model_name = f'msi_{model_type}_model.keras'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment
checkpoint = ModelCheckpoint(
    filepath=filepath,
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(
    factor=np.sqrt(0.1),
    cooldown=0,
    patience=5,
    min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Compile model
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])

# Run training
batch_size = 32  # Adjust as needed
epochs = 100     # Adjust as needed

history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(X_test, y_test),
                    shuffle=True,
                    callbacks=callbacks)
# Out:
# Learning rate:  0.001
# Learning rate:  0.001
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728465088.511983     103 service.cc:145] XLA service 0x78aeac0829f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728465088.512051     103 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1728465088.512055     103 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1728465104.509615     103 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.0119 - loss: 6.0992
# Epoch 1: val_accuracy improved from -inf to 0.01165, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 111s 407ms/step - accuracy: 0.0119 - loss: 6.0954 - val_accuracy: 0.0116 - val_loss: 4.9894 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.0409 - loss: 4.7766
# Epoch 2: val_accuracy improved from 0.01165 to 0.02882, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.0410 - loss: 4.7758 - val_accuracy: 0.0288 - val_loss: 4.7166 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 3/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.2350 - loss: 3.4991
# Epoch 3: val_accuracy improved from 0.02882 to 0.15144, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 83s 347ms/step - accuracy: 0.2351 - loss: 3.4980 - val_accuracy: 0.1514 - val_loss: 4.0192 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 4/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.4465 - loss: 2.3352
# Epoch 4: val_accuracy improved from 0.15144 to 0.22379, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.4466 - loss: 2.3348 - val_accuracy: 0.2238 - val_loss: 4.1874 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 5/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6017 - loss: 1.6419
# Epoch 5: val_accuracy improved from 0.22379 to 0.28081, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.6017 - loss: 1.6418 - val_accuracy: 0.2808 - val_loss: 3.8137 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 6/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.7190 - loss: 1.1835
# Epoch 6: val_accuracy improved from 0.28081 to 0.54384, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 345ms/step - accuracy: 0.7190 - loss: 1.1835 - val_accuracy: 0.5438 - val_loss: 1.9266 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 7/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7878 - loss: 0.9113
# Epoch 7: val_accuracy did not improve from 0.54384
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.7878 - loss: 0.9113 - val_accuracy: 0.3673 - val_loss: 4.0195 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 8/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8409 - loss: 0.6989
# Epoch 8: val_accuracy did not improve from 0.54384
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.8409 - loss: 0.6990 - val_accuracy: 0.4782 - val_loss: 2.7314 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 9/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8776 - loss: 0.5608
# Epoch 9: val_accuracy improved from 0.54384 to 0.61987, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.8776 - loss: 0.5608 - val_accuracy: 0.6199 - val_loss: 1.5723 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 10/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8954 - loss: 0.4719
# Epoch 10: val_accuracy did not improve from 0.61987
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.8954 - loss: 0.4719 - val_accuracy: 0.0883 - val_loss: 18.6662 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 11/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9269 - loss: 0.3863
# Epoch 11: val_accuracy did not improve from 0.61987
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9269 - loss: 0.3863 - val_accuracy: 0.3562 - val_loss: 6.1844 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 12/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9420 - loss: 0.3204
# Epoch 12: val_accuracy improved from 0.61987 to 0.66708, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 344ms/step - accuracy: 0.9420 - loss: 0.3205 - val_accuracy: 0.6671 - val_loss: 1.5311 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 13/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9504 - loss: 0.2991
# Epoch 13: val_accuracy did not improve from 0.66708
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9505 - loss: 0.2991 - val_accuracy: 0.6622 - val_loss: 1.5754 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 14/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9598 - loss: 0.2629
# Epoch 14: val_accuracy did not improve from 0.66708
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 83s 347ms/step - accuracy: 0.9598 - loss: 0.2630 - val_accuracy: 0.6622 - val_loss: 1.5681 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 15/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9644 - loss: 0.2540
# Epoch 15: val_accuracy did not improve from 0.66708
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9644 - loss: 0.2540 - val_accuracy: 0.5788 - val_loss: 2.6204 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 16/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9726 - loss: 0.2198
# Epoch 16: val_accuracy did not improve from 0.66708
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9725 - loss: 0.2200 - val_accuracy: 0.5279 - val_loss: 3.3177 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 17/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9471 - loss: 0.2966
# Epoch 17: val_accuracy did not improve from 0.66708
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9471 - loss: 0.2965 - val_accuracy: 0.6370 - val_loss: 1.9156 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 18/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9804 - loss: 0.1920
# Epoch 18: val_accuracy improved from 0.66708 to 0.76088, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 344ms/step - accuracy: 0.9804 - loss: 0.1919 - val_accuracy: 0.7609 - val_loss: 1.0958 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 19/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9844 - loss: 0.1785
# Epoch 19: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9843 - loss: 0.1787 - val_accuracy: 0.5316 - val_loss: 3.1085 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 20/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9693 - loss: 0.2165
# Epoch 20: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9693 - loss: 0.2164 - val_accuracy: 0.7566 - val_loss: 1.0479 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 21/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9864 - loss: 0.1659
# Epoch 21: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9864 - loss: 0.1659 - val_accuracy: 0.5169 - val_loss: 3.0640 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 22/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9732 - loss: 0.2037
# Epoch 22: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9732 - loss: 0.2039 - val_accuracy: 0.5549 - val_loss: 2.7896 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 23/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9766 - loss: 0.1943
# Epoch 23: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9766 - loss: 0.1943 - val_accuracy: 0.7456 - val_loss: 1.2418 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 24/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9783 - loss: 0.2097
# Epoch 24: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9783 - loss: 0.2097 - val_accuracy: 0.3587 - val_loss: 13.0664 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 25/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9705 - loss: 0.2186
# Epoch 25: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9705 - loss: 0.2185 - val_accuracy: 0.7174 - val_loss: 1.3556 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 26/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9900 - loss: 0.1456
# Epoch 26: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9900 - loss: 0.1456 - val_accuracy: 0.4654 - val_loss: 3.8980 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 27/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9863 - loss: 0.1555
# Epoch 27: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9863 - loss: 0.1556 - val_accuracy: 0.7137 - val_loss: 1.4775 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 28/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9727 - loss: 0.2190
# Epoch 28: val_accuracy did not improve from 0.76088
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9726 - loss: 0.2190 - val_accuracy: 0.5861 - val_loss: 2.3846 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 29/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9835 - loss: 0.1633
# Epoch 29: val_accuracy improved from 0.76088 to 0.80258, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9835 - loss: 0.1632 - val_accuracy: 0.8026 - val_loss: 0.9722 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 30/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9934 - loss: 0.1317
# Epoch 30: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9934 - loss: 0.1317 - val_accuracy: 0.7308 - val_loss: 1.6390 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 31/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9804 - loss: 0.1761
# Epoch 31: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9804 - loss: 0.1761 - val_accuracy: 0.6383 - val_loss: 2.2682 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 32/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9834 - loss: 0.1578
# Epoch 32: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9834 - loss: 0.1578 - val_accuracy: 0.7290 - val_loss: 1.3282 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 33/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9924 - loss: 0.1273
# Epoch 33: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9924 - loss: 0.1273 - val_accuracy: 0.7394 - val_loss: 1.4133 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 34/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9811 - loss: 0.1578
# Epoch 34: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9811 - loss: 0.1578 - val_accuracy: 0.6720 - val_loss: 1.6481 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 35/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9827 - loss: 0.1660
# Epoch 35: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9827 - loss: 0.1660 - val_accuracy: 0.3335 - val_loss: 8.6062 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 36/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9846 - loss: 0.1539
# Epoch 36: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9846 - loss: 0.1539 - val_accuracy: 0.7186 - val_loss: 1.4886 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 37/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9886 - loss: 0.1410
# Epoch 37: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9886 - loss: 0.1410 - val_accuracy: 0.5702 - val_loss: 2.7628 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 38/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9856 - loss: 0.1359
# Epoch 38: val_accuracy did not improve from 0.80258
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9856 - loss: 0.1359 - val_accuracy: 0.7229 - val_loss: 1.4153 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 39/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9944 - loss: 0.1106
# Epoch 39: val_accuracy improved from 0.80258 to 0.80564, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9944 - loss: 0.1106 - val_accuracy: 0.8056 - val_loss: 1.0037 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 40/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9996 - loss: 0.0901
# Epoch 40: val_accuracy improved from 0.80564 to 0.86511, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9996 - loss: 0.0900 - val_accuracy: 0.8651 - val_loss: 0.6366 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 41/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9999 - loss: 0.0833
# Epoch 41: val_accuracy improved from 0.86511 to 0.87431, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9999 - loss: 0.0833 - val_accuracy: 0.8743 - val_loss: 0.5912 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 42/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9998 - loss: 0.0786
# Epoch 42: val_accuracy improved from 0.87431 to 0.87615, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9998 - loss: 0.0786 - val_accuracy: 0.8761 - val_loss: 0.5837 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 43/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0739
# Epoch 43: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9999 - loss: 0.0739 - val_accuracy: 0.8700 - val_loss: 0.5910 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 44/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0695
# Epoch 44: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9999 - loss: 0.0695 - val_accuracy: 0.8608 - val_loss: 0.6931 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 45/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9538 - loss: 0.2373
# Epoch 45: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9538 - loss: 0.2377 - val_accuracy: 0.5953 - val_loss: 2.4342 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 46/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9782 - loss: 0.1664
# Epoch 46: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9782 - loss: 0.1663 - val_accuracy: 0.6787 - val_loss: 1.6506 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 47/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9962 - loss: 0.0974
# Epoch 47: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9962 - loss: 0.0974 - val_accuracy: 0.7615 - val_loss: 1.2543 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 48/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9970 - loss: 0.0962
# Epoch 48: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9970 - loss: 0.0961 - val_accuracy: 0.8197 - val_loss: 0.8404 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 49/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9960 - loss: 0.0908
# Epoch 49: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9960 - loss: 0.0909 - val_accuracy: 0.5543 - val_loss: 3.3049 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 50/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9771 - loss: 0.1763
# Epoch 50: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9771 - loss: 0.1763 - val_accuracy: 0.6505 - val_loss: 1.8101 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 51/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9897 - loss: 0.1173
# Epoch 51: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9897 - loss: 0.1173 - val_accuracy: 0.7823 - val_loss: 0.9546 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 52/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9968 - loss: 0.0946
# Epoch 52: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9968 - loss: 0.0946 - val_accuracy: 0.7799 - val_loss: 1.0692 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 53/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9931 - loss: 0.1056
# Epoch 53: val_accuracy did not improve from 0.87615
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9931 - loss: 0.1055 - val_accuracy: 0.8332 - val_loss: 0.7180 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 54/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9999 - loss: 0.0743
# Epoch 54: val_accuracy improved from 0.87615 to 0.87676, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9999 - loss: 0.0743 - val_accuracy: 0.8768 - val_loss: 0.5805 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 55/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9966 - loss: 0.0805
# Epoch 55: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 82s 345ms/step - accuracy: 0.9966 - loss: 0.0806 - val_accuracy: 0.7627 - val_loss: 1.3387 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 56/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9780 - loss: 0.1388
# Epoch 56: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9780 - loss: 0.1388 - val_accuracy: 0.6634 - val_loss: 2.0124 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 57/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9754 - loss: 0.1506
# Epoch 57: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 71s 348ms/step - accuracy: 0.9754 - loss: 0.1506 - val_accuracy: 0.7094 - val_loss: 1.6505 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 58/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9894 - loss: 0.1078
# Epoch 58: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9894 - loss: 0.1078 - val_accuracy: 0.6757 - val_loss: 1.7491 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 59/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9933 - loss: 0.1027
# Epoch 59: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9933 - loss: 0.1027 - val_accuracy: 0.8210 - val_loss: 0.8470 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 60/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9960 - loss: 0.0861
# Epoch 60: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9960 - loss: 0.0861 - val_accuracy: 0.7008 - val_loss: 1.5782 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 61/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9945 - loss: 0.0896
# Epoch 61: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9945 - loss: 0.0897 - val_accuracy: 0.6260 - val_loss: 2.2627 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 62/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9885 - loss: 0.1054
# Epoch 62: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9885 - loss: 0.1054 - val_accuracy: 0.7517 - val_loss: 1.1491 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 63/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9946 - loss: 0.0878
# Epoch 63: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9946 - loss: 0.0878 - val_accuracy: 0.4979 - val_loss: 6.1510 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 64/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9972 - loss: 0.0794
# Epoch 64: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9972 - loss: 0.0795 - val_accuracy: 0.6426 - val_loss: 2.2492 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 65/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9879 - loss: 0.1052
# Epoch 65: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 341ms/step - accuracy: 0.9879 - loss: 0.1052 - val_accuracy: 0.6205 - val_loss: 2.3988 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 66/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9883 - loss: 0.1057
# Epoch 66: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9883 - loss: 0.1057 - val_accuracy: 0.7198 - val_loss: 1.5848 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 67/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9943 - loss: 0.0878
# Epoch 67: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9943 - loss: 0.0878 - val_accuracy: 0.8142 - val_loss: 0.8885 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 68/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9976 - loss: 0.0768
# Epoch 68: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9976 - loss: 0.0768 - val_accuracy: 0.8418 - val_loss: 0.7403 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 69/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9579 - loss: 0.2314
# Epoch 69: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 341ms/step - accuracy: 0.9579 - loss: 0.2313 - val_accuracy: 0.7676 - val_loss: 1.1650 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 70/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9988 - loss: 0.0857
# Epoch 70: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9988 - loss: 0.0857 - val_accuracy: 0.8424 - val_loss: 0.6900 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 71/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9965 - loss: 0.0881
# Epoch 71: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9965 - loss: 0.0880 - val_accuracy: 0.8345 - val_loss: 0.7183 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 72/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9989 - loss: 0.0729
# Epoch 72: val_accuracy did not improve from 0.87676
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9989 - loss: 0.0729 - val_accuracy: 0.8547 - val_loss: 0.6816 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 73/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9998 - loss: 0.0669
# Epoch 73: val_accuracy improved from 0.87676 to 0.87983, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9998 - loss: 0.0669 - val_accuracy: 0.8798 - val_loss: 0.5544 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 74/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9995 - loss: 0.0726
# Epoch 74: val_accuracy improved from 0.87983 to 0.88780, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 0.9995 - loss: 0.0726 - val_accuracy: 0.8878 - val_loss: 0.5172 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 75/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 1.0000 - loss: 0.0595
# Epoch 75: val_accuracy improved from 0.88780 to 0.89086, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 343ms/step - accuracy: 1.0000 - loss: 0.0595 - val_accuracy: 0.8909 - val_loss: 0.5002 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 76/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 1.0000 - loss: 0.0564
# Epoch 76: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 1.0000 - loss: 0.0564 - val_accuracy: 0.8909 - val_loss: 0.5007 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 77/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9997 - loss: 0.0535
# Epoch 77: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 341ms/step - accuracy: 0.9997 - loss: 0.0535 - val_accuracy: 0.8829 - val_loss: 0.5536 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 78/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9998 - loss: 0.0505
# Epoch 78: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9998 - loss: 0.0505 - val_accuracy: 0.8903 - val_loss: 0.5078 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 79/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0476
# Epoch 79: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9999 - loss: 0.0476 - val_accuracy: 0.8743 - val_loss: 0.6163 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 80/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0466
# Epoch 80: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9999 - loss: 0.0465 - val_accuracy: 0.8216 - val_loss: 0.8937 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 81/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9252 - loss: 0.3477
# Epoch 81: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9253 - loss: 0.3473 - val_accuracy: 0.5297 - val_loss: 3.3380 - learning_rate: 0.0010
# Learning rate:  0.0001
# Epoch 82/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9916 - loss: 0.0903
# Epoch 82: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9917 - loss: 0.0902 - val_accuracy: 0.8614 - val_loss: 0.5745 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 83/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9998 - loss: 0.0683
# Epoch 83: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9998 - loss: 0.0683 - val_accuracy: 0.8645 - val_loss: 0.5527 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 1.0000 - loss: 0.0662
# Epoch 84: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 1.0000 - loss: 0.0661 - val_accuracy: 0.8663 - val_loss: 0.5416 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 85/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 1.0000 - loss: 0.0642
# Epoch 85: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 1.0000 - loss: 0.0642 - val_accuracy: 0.8663 - val_loss: 0.5334 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 86/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9999 - loss: 0.0632
# Epoch 86: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9999 - loss: 0.0632 - val_accuracy: 0.8712 - val_loss: 0.5295 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9997 - loss: 0.0624
# Epoch 87: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9997 - loss: 0.0624 - val_accuracy: 0.8712 - val_loss: 0.5276 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 88/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0617
# Epoch 88: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9999 - loss: 0.0617 - val_accuracy: 0.8719 - val_loss: 0.5248 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 89/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0603
# Epoch 89: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9999 - loss: 0.0603 - val_accuracy: 0.8737 - val_loss: 0.5235 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 90/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9997 - loss: 0.0596
# Epoch 90: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9997 - loss: 0.0596 - val_accuracy: 0.8749 - val_loss: 0.5196 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 91/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9998 - loss: 0.0586
# Epoch 91: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9998 - loss: 0.0586 - val_accuracy: 0.8768 - val_loss: 0.5188 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 92/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9998 - loss: 0.0576
# Epoch 92: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9998 - loss: 0.0576 - val_accuracy: 0.8792 - val_loss: 0.5184 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 93/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0566
# Epoch 93: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9999 - loss: 0.0566 - val_accuracy: 0.8817 - val_loss: 0.5194 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 94/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 1.0000 - loss: 0.0554
# Epoch 94: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 1.0000 - loss: 0.0554 - val_accuracy: 0.8798 - val_loss: 0.5185 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 95/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0545
# Epoch 95: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9999 - loss: 0.0545 - val_accuracy: 0.8792 - val_loss: 0.5180 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 96/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9999 - loss: 0.0534
# Epoch 96: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9999 - loss: 0.0534 - val_accuracy: 0.8804 - val_loss: 0.5170 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 97/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 1.0000 - loss: 0.0525
# Epoch 97: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 1.0000 - loss: 0.0525 - val_accuracy: 0.8811 - val_loss: 0.5174 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 98/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 1.0000 - loss: 0.0512
# Epoch 98: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 1.0000 - loss: 0.0512 - val_accuracy: 0.8835 - val_loss: 0.5166 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 99/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9999 - loss: 0.0501
# Epoch 99: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9999 - loss: 0.0501 - val_accuracy: 0.8829 - val_loss: 0.5162 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 100/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9996 - loss: 0.0491
# Epoch 100: val_accuracy did not improve from 0.89086
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9996 - loss: 0.0491 - val_accuracy: 0.8817 - val_loss: 0.5142 - learning_rate: 3.1623e-05

# %%
# Score trained model. 
scores = model.evaluate(X_test, y_test, verbose = 1) 
print('Test loss:', scores[0]) 
print('Test accuracy:', scores[1])
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.8735 - loss: 0.5755
# Test loss: 0.5141823291778564
# Test accuracy: 0.8816676735877991
