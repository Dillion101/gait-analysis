# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
import pandas as pd
import cv2
from sklearn.model_selection import train_test_split

def load_and_preprocess_data(csv_path, image_base_path, angles_to_process=None):
    # Load the metadata CSV
    df = pd.read_csv(csv_path)
    angle_groups = df.groupby('cam_angle')
    
    # If angles_to_process is not specified, process all angles
    if angles_to_process is None:
        angles_to_process = angle_groups.groups.keys()
    else:
        angles_to_process = [angles_to_process] if isinstance(angles_to_process, (int, float)) else angles_to_process
    
    X_all, y_all = [], []
    
    # Iterate through each angle and process
    for angle in angles_to_process:
        if angle not in angle_groups.groups:
            print(f"Angle {angle} not found in the dataset. Skipping.")
            continue
        print(f"Processing angle: {angle}")
        group = angle_groups.get_group(angle)
        
        for _, row in group.iterrows():
            image_path = os.path.join(image_base_path, row['image_filename'])
            try:
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    img = cv2.resize(img, (240, 240))
                    img = img.astype('float32') / 255.0  # Normalize to [0, 1]
                    X_all.append(img)
                    y_all.append(row['label'])
                else:
                    print(f"Failed to load image: {image_path}")
            except Exception as e:
                print(f"Error processing image {image_path}: {str(e)}")
    
    if not X_all:
        raise ValueError("No valid images found in the dataset.")
    
    X_all = np.array(X_all)
    y_all = np.array(y_all)
    
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=42)
    
    # Reshape the data to match the CIFAR-10 format
    X_train = X_train.reshape(-1, 240, 240, 1)
    X_test = X_test.reshape(-1, 240, 240, 1)
    y_train = y_train.reshape(-1, 1)
    y_test = y_test.reshape(-1, 1)
    
    return (X_train, y_train), (X_test, y_test)

def load_data():
    # Define the paths
    csv_path = '/kaggle/input/processed-msi-dataset/msi_metadata.csv'
    image_base_path = '/kaggle/input/processed-msi-dataset/msi_images'
    
    # Specify the angles to process
    angles_to_process = [0, 18, 36, 54, 72, 90, 108, 126, 144, 162, 180]
    
    # Load and preprocess the data
    return load_and_preprocess_data(csv_path, image_base_path, angles_to_process)

# Usage example:
(X_train, y_train), (X_test, y_test) = load_data()

# Print summary of the loaded data
print("\nSummary of loaded data:")
print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")
print(f"Image shape: {X_train.shape[1:]}")
print(f"Label shape: {y_train.shape[1:]}")
# Out:
# Processing angle: 0
# Processing angle: 18
# Processing angle: 36
# Processing angle: 54
# Processing angle: 72
# Processing angle: 90
# Processing angle: 108
# Processing angle: 126
# Processing angle: 144
# Processing angle: 162
# Processing angle: 180
#
# Summary of loaded data:
# Training samples: 6523
# Testing samples: 1631
# Image shape: (240, 240, 1)
# Label shape: (1,)

# %%
# Setting Training Hyperparameters 
batch_size = 32 # original ResNet paper uses batch_size = 128 for training 
epochs = 100
data_augmentation = True
num_classes = 10

# Data Preprocessing 
subtract_pixel_mean = True
n = 3

# Select ResNet Version 
version = 1

# Computed depth of 
if version == 1: 
	depth = n * 6 + 2
elif version == 2: 
	depth = n * 9 + 2

# Model name, depth and version 
model_type = 'ResNet % dv % d' % (depth, version) 

# Load the CIFAR-10 data. 
(x_train, y_train), (x_test, y_test) = load_data()

# Input image dimensions. 
input_shape = x_train.shape[1:] 

# Normalize data. 
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled 
if subtract_pixel_mean: 
	x_train_mean = np.mean(x_train, axis = 0) 
	x_train -= x_train_mean 
	x_test -= x_train_mean 

# Print Training and Test Samples 
print('x_train shape:', x_train.shape) 
print(x_train.shape[0], 'train samples') 
print(x_test.shape[0], 'test samples') 
print('y_train shape:', y_train.shape) 

# Convert class vectors to binary class matrices. 
y_train = keras.utils.to_categorical(y_train, num_classes) 
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Processing angle: 0
# Processing angle: 18
# Processing angle: 36
# Processing angle: 54
# Processing angle: 72
# Processing angle: 90
# Processing angle: 108
# Processing angle: 126
# Processing angle: 144
# Processing angle: 162
# Processing angle: 180
# x_train shape: (6523, 240, 240, 1)
# 6523 train samples
# 1631 test samples
# y_train shape: (6523, 1)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 46
#      43 print('y_train shape:', y_train.shape)
#      45 # Convert class vectors to binary class matrices.
# ---> 46 y_train = keras.utils.to_categorical(y_train, num_classes)
#      47 y_test = keras.utils.to_categorical(y_test, num_classes)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/numerical_utils.py:89, in to_categorical(x, num_classes)
#      87 batch_size = x.shape[0]
#      88 categorical = np.zeros((batch_size, num_classes))
# ---> 89 categorical[np.arange(batch_size), x] = 1
#      90 output_shape = input_shape + (num_classes,)
#      91 categorical = np.reshape(categorical, output_shape)
#
# IndexError: index 33 is out of bounds for axis 1 with size 10

# %%
import pandas as pd
import numpy as np
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

def load_and_preprocess_data(csv_path, image_base_path, angles_to_process=None):
    # Load the metadata CSV
    df = pd.read_csv(csv_path)
    angle_groups = df.groupby('cam_angle')
    
    # If angles_to_process is not specified, process all angles
    if angles_to_process is None:
        angles_to_process = angle_groups.groups.keys()
    else:
        angles_to_process = [angles_to_process] if isinstance(angles_to_process, (int, float)) else angles_to_process
    
    X_all, y_all = [], []
    
    # Iterate through each angle and process
    for angle in angles_to_process:
        if angle not in angle_groups.groups:
            print(f"Angle {angle} not found in the dataset. Skipping.")
            continue
        print(f"Processing angle: {angle}")
        group = angle_groups.get_group(angle)
        
        for _, row in group.iterrows():
            image_path = os.path.join(image_base_path, row['image_filename'])
            try:
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    img = cv2.resize(img, (240, 240))
                    img = img.astype('float32') / 255.0  # Normalize to [0, 1]
                    X_all.append(img)
                    y_all.append(row['label'])
                else:
                    print(f"Failed to load image: {image_path}")
            except Exception as e:
                print(f"Error processing image {image_path}: {str(e)}")
    
    if not X_all:
        raise ValueError("No valid images found in the dataset.")
    
    X_all = np.array(X_all)
    y_all = np.array(y_all)
    
    # Use LabelEncoder to ensure labels are zero-indexed
    label_encoder = LabelEncoder()
    y_all = label_encoder.fit_transform(y_all)
    
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=42)
    
    # Reshape the data to match the CIFAR-10 format
    X_train = X_train.reshape(-1, 240, 240, 1)
    X_test = X_test.reshape(-1, 240, 240, 1)
    
    # Get the number of unique classes
    num_classes = len(label_encoder.classes_)
    
    return (X_train, y_train), (X_test, y_test), num_classes

def load_data():
    # Define the paths
    csv_path = '/kaggle/input/processed-msi-dataset/msi_metadata.csv'
    image_base_path = '/kaggle/input/processed-msi-dataset/msi_images'
    
    # Specify the angles to process
    angles_to_process = [0, 18, 36, 54, 72, 90, 108, 126, 144, 162, 180]
    
    # Load and preprocess the data
    return load_and_preprocess_data(csv_path, image_base_path, angles_to_process)

# Usage example:
(X_train, y_train), (X_test, y_test), num_classes = load_data()

# Print summary of the loaded data
print("\nSummary of loaded data:")
print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")
print(f"Image shape: {X_train.shape[1:]}")
print(f"Number of classes: {num_classes}")

# Data Preprocessing
subtract_pixel_mean = True

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(X_train, axis=0)
    X_train -= x_train_mean
    X_test -= x_train_mean

# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# Print shapes after preprocessing
print("\nAfter preprocessing:")
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# Processing angle: 0
# Processing angle: 18
# Processing angle: 36
# Processing angle: 54
# Processing angle: 72
# Processing angle: 90
# Processing angle: 108
# Processing angle: 126
# Processing angle: 144
# Processing angle: 162
# Processing angle: 180
#
# Summary of loaded data:
# Training samples: 6523
# Testing samples: 1631
# Image shape: (240, 240, 1)
# Number of classes: 124
#
# After preprocessing:
# X_train shape: (6523, 240, 240, 1)
# 6523 train samples
# 1631 test samples
# y_train shape: (6523, 124)

# %%
# Setting LR for different number of Epochs 
def lr_schedule(epoch): 
	lr = 1e-3
	if epoch > 180: 
		lr *= 0.5e-3
	elif epoch > 160: 
		lr *= 1e-3
	elif epoch > 120: 
		lr *= 1e-2
	elif epoch > 80: 
		lr *= 1e-1
	print('Learning rate: ', lr) 
	return lr

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation
from tensorflow.keras.regularizers import l2

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    Args:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or bn-activation-conv (False)

    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Activation, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def resnet_v1(input_shape, depth, num_classes=10):
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])')
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Activation, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def resnet_v1(input_shape, depth, num_classes=124):  # Changed default to 124
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])')
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Create the model
input_shape = x_train.shape[1:]  # Assuming x_train is your input data
depth = 20  # or whatever depth you're using
model = resnet_v1(input_shape=input_shape, depth=depth, num_classes=124)

# Print model summary
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 240, 240,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 240, 240,  │        160 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_19[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_20[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 240, 240,  │          0 │ activation_19[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 240, 240,  │          0 │ add_9[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_21[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_22[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 240, 240,  │          0 │ activation_21[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 240, 240,  │          0 │ add_10[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_23[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_24[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 240, 240,  │          0 │ activation_23[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 240, 240,  │          0 │ add_11[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 120, 120,  │      4,640 │ activation_25[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_26[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 120, 120,  │        544 │ activation_25[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 120, 120,  │          0 │ conv2d_30[0][0],  │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 120, 120,  │          0 │ add_12[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_27[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_28[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 120, 120,  │          0 │ activation_27[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 120, 120,  │          0 │ add_13[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_29[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_30[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 120, 120,  │          0 │ activation_29[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 120, 120,  │          0 │ add_14[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 60, 60,    │     18,496 │ activation_31[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_32[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 60, 60,    │      2,112 │ activation_31[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 60, 60,    │          0 │ conv2d_37[0][0],  │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 60, 60,    │          0 │ add_15[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_33[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_34[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 60, 60,    │          0 │ activation_33[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 60, 60,    │          0 │ add_16[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_35[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_36[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 60, 60,    │          0 │ activation_35[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 60, 60,    │          0 │ add_17[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 7, 7, 64)  │          0 │ activation_37[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 3136)      │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 124)       │    388,988 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 662,492 (2.53 MB)
#  Trainable params: 661,116 (2.52 MB)
#  Non-trainable params: 1,376 (5.38 KB)

# %%
import os
import numpy as np
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau

# Learning rate schedule
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Set up model name and save directory
version = 1  # Assuming you're using version 1
depth = 20  # Assuming you're using depth 20
model_type = f'ResNet{depth}v{version}'
model_name = f'msi_{model_type}_model.keras'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment
checkpoint = ModelCheckpoint(
    filepath=filepath,
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(
    factor=np.sqrt(0.1),
    cooldown=0,
    patience=5,
    min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Compile model
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])

# Run training
batch_size = 32  # Adjust as needed
epochs = 100     # Adjust as needed

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    shuffle=True,
                    callbacks=callbacks)
# Out:
# Learning rate:  0.001
# Learning rate:  0.001
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727392690.864909     172 service.cc:145] XLA service 0x7c744c084310 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727392690.864978     172 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1727392690.864983     172 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1727392707.348827     172 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.0163 - loss: 6.2690
# Epoch 1: val_accuracy improved from -inf to 0.00429, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 116s 422ms/step - accuracy: 0.0164 - loss: 6.2640 - val_accuracy: 0.0043 - val_loss: 4.9886 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.1094 - loss: 4.1116
# Epoch 2: val_accuracy improved from 0.00429 to 0.00736, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 338ms/step - accuracy: 0.1095 - loss: 4.1109 - val_accuracy: 0.0074 - val_loss: 4.9917 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 3/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.2798 - loss: 3.1567
# Epoch 3: val_accuracy improved from 0.00736 to 0.03740, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 338ms/step - accuracy: 0.2799 - loss: 3.1561 - val_accuracy: 0.0374 - val_loss: 5.3883 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 4/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.4797 - loss: 2.1847
# Epoch 4: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.4797 - loss: 2.1846 - val_accuracy: 0.0184 - val_loss: 94.5381 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 5/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6296 - loss: 1.5244
# Epoch 5: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.6296 - loss: 1.5242 - val_accuracy: 0.0325 - val_loss: 7.5516 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 6/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7410 - loss: 1.0853
# Epoch 6: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.7410 - loss: 1.0854 - val_accuracy: 0.0104 - val_loss: 230.8760 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 7/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8274 - loss: 0.7806
# Epoch 7: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.8274 - loss: 0.7807 - val_accuracy: 0.0135 - val_loss: 270.8746 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 8/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8595 - loss: 0.6438
# Epoch 8: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.8595 - loss: 0.6438 - val_accuracy: 0.0104 - val_loss: 227.4394 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 9/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8986 - loss: 0.5004
# Epoch 9: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.8985 - loss: 0.5005 - val_accuracy: 0.0061 - val_loss: 461.5787 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 10/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9270 - loss: 0.4053
# Epoch 10: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9270 - loss: 0.4054 - val_accuracy: 0.0116 - val_loss: 222.2194 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 11/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9429 - loss: 0.3424
# Epoch 11: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9429 - loss: 0.3425 - val_accuracy: 0.0129 - val_loss: 172.6001 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 12/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9357 - loss: 0.3521
# Epoch 12: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9357 - loss: 0.3521 - val_accuracy: 0.0135 - val_loss: 1037.7402 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 13/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9697 - loss: 0.2490
# Epoch 13: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9697 - loss: 0.2490 - val_accuracy: 0.0270 - val_loss: 45.8781 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 14/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9580 - loss: 0.2792
# Epoch 14: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9579 - loss: 0.2792 - val_accuracy: 0.0116 - val_loss: 233.4084 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 15/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9807 - loss: 0.2106
# Epoch 15: val_accuracy did not improve from 0.03740
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9807 - loss: 0.2106 - val_accuracy: 0.0116 - val_loss: 107.9461 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 16/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9749 - loss: 0.2277
# Epoch 16: val_accuracy improved from 0.03740 to 0.06254, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9748 - loss: 0.2277 - val_accuracy: 0.0625 - val_loss: 7.9530 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 17/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9717 - loss: 0.2152
# Epoch 17: val_accuracy did not improve from 0.06254
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9717 - loss: 0.2153 - val_accuracy: 0.0092 - val_loss: 270.6689 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 18/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9727 - loss: 0.2293
# Epoch 18: val_accuracy did not improve from 0.06254
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9727 - loss: 0.2294 - val_accuracy: 0.0110 - val_loss: 314.5204 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 19/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9665 - loss: 0.2623
# Epoch 19: val_accuracy did not improve from 0.06254
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9665 - loss: 0.2622 - val_accuracy: 0.0098 - val_loss: 30.9289 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 20/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9803 - loss: 0.1986
# Epoch 20: val_accuracy did not improve from 0.06254
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9802 - loss: 0.1986 - val_accuracy: 0.0405 - val_loss: 73.4929 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 21/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9783 - loss: 0.1999
# Epoch 21: val_accuracy did not improve from 0.06254
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 334ms/step - accuracy: 0.9783 - loss: 0.1999 - val_accuracy: 0.0435 - val_loss: 17.6729 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 22/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9719 - loss: 0.2173
# Epoch 22: val_accuracy did not improve from 0.06254
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 334ms/step - accuracy: 0.9718 - loss: 0.2174 - val_accuracy: 0.0123 - val_loss: 330.1210 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 23/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9825 - loss: 0.1847
# Epoch 23: val_accuracy did not improve from 0.06254
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 334ms/step - accuracy: 0.9825 - loss: 0.1847 - val_accuracy: 0.0276 - val_loss: 8.9930 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 24/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9810 - loss: 0.1773
# Epoch 24: val_accuracy improved from 0.06254 to 0.17535, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9811 - loss: 0.1772 - val_accuracy: 0.1754 - val_loss: 7.9857 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 25/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9890 - loss: 0.1616
# Epoch 25: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 334ms/step - accuracy: 0.9890 - loss: 0.1616 - val_accuracy: 0.0656 - val_loss: 35.5986 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 26/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9859 - loss: 0.1593
# Epoch 26: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 336ms/step - accuracy: 0.9859 - loss: 0.1593 - val_accuracy: 0.0043 - val_loss: 128.7088 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 27/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9890 - loss: 0.1534
# Epoch 27: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9890 - loss: 0.1534 - val_accuracy: 0.0092 - val_loss: 1562.4445 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 28/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9880 - loss: 0.1547
# Epoch 28: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9880 - loss: 0.1548 - val_accuracy: 0.0092 - val_loss: 2357.2205 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 29/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9762 - loss: 0.1940
# Epoch 29: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9762 - loss: 0.1940 - val_accuracy: 0.0110 - val_loss: 548.6411 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 30/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9873 - loss: 0.1538
# Epoch 30: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9873 - loss: 0.1538 - val_accuracy: 0.0061 - val_loss: 379.4188 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 31/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9818 - loss: 0.1830
# Epoch 31: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 334ms/step - accuracy: 0.9818 - loss: 0.1831 - val_accuracy: 0.0061 - val_loss: 491.4561 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 32/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9802 - loss: 0.1707
# Epoch 32: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9802 - loss: 0.1707 - val_accuracy: 0.0067 - val_loss: 239.7848 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 33/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9918 - loss: 0.1394
# Epoch 33: val_accuracy did not improve from 0.17535
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9918 - loss: 0.1393 - val_accuracy: 0.0215 - val_loss: 45.0230 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 34/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9987 - loss: 0.1102
# Epoch 34: val_accuracy improved from 0.17535 to 0.19559, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9987 - loss: 0.1102 - val_accuracy: 0.1956 - val_loss: 6.1622 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 35/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9992 - loss: 0.1011
# Epoch 35: val_accuracy did not improve from 0.19559
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9992 - loss: 0.1010 - val_accuracy: 0.0233 - val_loss: 177.0662 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 36/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 1.0000 - loss: 0.0906
# Epoch 36: val_accuracy improved from 0.19559 to 0.29491, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 1.0000 - loss: 0.0906 - val_accuracy: 0.2949 - val_loss: 11.3605 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 37/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 1.0000 - loss: 0.0855
# Epoch 37: val_accuracy improved from 0.29491 to 0.69221, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 1.0000 - loss: 0.0855 - val_accuracy: 0.6922 - val_loss: 1.7408 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 38/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9999 - loss: 0.0805
# Epoch 38: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 334ms/step - accuracy: 0.9999 - loss: 0.0805 - val_accuracy: 0.0938 - val_loss: 20.8057 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 39/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9749 - loss: 0.1698
# Epoch 39: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9748 - loss: 0.1704 - val_accuracy: 0.0061 - val_loss: 407.6473 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 40/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9614 - loss: 0.2360
# Epoch 40: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9615 - loss: 0.2358 - val_accuracy: 0.0098 - val_loss: 242.0799 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 41/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9866 - loss: 0.1386
# Epoch 41: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9866 - loss: 0.1387 - val_accuracy: 0.0061 - val_loss: 54.2192 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 42/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9904 - loss: 0.1297
# Epoch 42: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9904 - loss: 0.1296 - val_accuracy: 0.0478 - val_loss: 20.3708 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 43/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9993 - loss: 0.0940
# Epoch 43: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9993 - loss: 0.0940 - val_accuracy: 0.1643 - val_loss: 15.9350 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 44/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9977 - loss: 0.0922
# Epoch 44: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9977 - loss: 0.0922 - val_accuracy: 0.0061 - val_loss: 49.8770 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 45/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9843 - loss: 0.1373
# Epoch 45: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9842 - loss: 0.1375 - val_accuracy: 0.0080 - val_loss: 756.4506 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 46/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9796 - loss: 0.1617
# Epoch 46: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9796 - loss: 0.1617 - val_accuracy: 0.0061 - val_loss: 447.8166 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 47/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9909 - loss: 0.1182
# Epoch 47: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9909 - loss: 0.1182 - val_accuracy: 0.0061 - val_loss: 128.0546 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 48/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9956 - loss: 0.0999
# Epoch 48: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9956 - loss: 0.1000 - val_accuracy: 0.0092 - val_loss: 645.5519 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 49/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9925 - loss: 0.1103
# Epoch 49: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9925 - loss: 0.1104 - val_accuracy: 0.0092 - val_loss: 935.7900 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 50/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9801 - loss: 0.1613
# Epoch 50: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9800 - loss: 0.1613 - val_accuracy: 0.0110 - val_loss: 2342.2947 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 51/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9913 - loss: 0.1247
# Epoch 51: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9913 - loss: 0.1247 - val_accuracy: 0.0123 - val_loss: 993.1392 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 52/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9929 - loss: 0.1070
# Epoch 52: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9929 - loss: 0.1070 - val_accuracy: 0.0582 - val_loss: 13.3462 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 53/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9964 - loss: 0.0908
# Epoch 53: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9964 - loss: 0.0908 - val_accuracy: 0.0129 - val_loss: 153.2773 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 54/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 1.0000 - loss: 0.0767
# Epoch 54: val_accuracy did not improve from 0.69221
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 1.0000 - loss: 0.0767 - val_accuracy: 0.0245 - val_loss: 131.0103 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 55/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 1.0000 - loss: 0.0716
# Epoch 55: val_accuracy improved from 0.69221 to 0.77682, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 1.0000 - loss: 0.0716 - val_accuracy: 0.7768 - val_loss: 1.1651 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 56/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 1.0000 - loss: 0.0674
# Epoch 56: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 333ms/step - accuracy: 0.9999 - loss: 0.0674 - val_accuracy: 0.0693 - val_loss: 26.6756 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 57/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9880 - loss: 0.1053
# Epoch 57: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9879 - loss: 0.1056 - val_accuracy: 0.0129 - val_loss: 479.4956 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 58/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9732 - loss: 0.1603
# Epoch 58: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9732 - loss: 0.1602 - val_accuracy: 0.0061 - val_loss: 367.9906 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 59/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9915 - loss: 0.1158
# Epoch 59: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9915 - loss: 0.1158 - val_accuracy: 0.0061 - val_loss: 1010.6852 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 60/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9965 - loss: 0.0902
# Epoch 60: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9965 - loss: 0.0902 - val_accuracy: 0.0080 - val_loss: 83.8001 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 61/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9904 - loss: 0.1029
# Epoch 61: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9904 - loss: 0.1028 - val_accuracy: 0.0245 - val_loss: 66.9357 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 62/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9940 - loss: 0.0931
# Epoch 62: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9940 - loss: 0.0932 - val_accuracy: 0.0104 - val_loss: 15.5961 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 63/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9917 - loss: 0.1007
# Epoch 63: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9917 - loss: 0.1007 - val_accuracy: 0.0061 - val_loss: 234.5560 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 64/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9962 - loss: 0.0827
# Epoch 64: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9961 - loss: 0.0827 - val_accuracy: 0.0055 - val_loss: 220.2067 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 65/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9953 - loss: 0.0848
# Epoch 65: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9953 - loss: 0.0848 - val_accuracy: 0.0098 - val_loss: 71.3292 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 66/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9964 - loss: 0.0836
# Epoch 66: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9964 - loss: 0.0836 - val_accuracy: 0.0086 - val_loss: 74.8852 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 67/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9911 - loss: 0.0963
# Epoch 67: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9911 - loss: 0.0964 - val_accuracy: 0.0061 - val_loss: 891.3273 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 68/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9827 - loss: 0.1293
# Epoch 68: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9828 - loss: 0.1292 - val_accuracy: 0.0061 - val_loss: 147.2688 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 69/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9960 - loss: 0.0841
# Epoch 69: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9960 - loss: 0.0842 - val_accuracy: 0.0074 - val_loss: 89.1523 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 70/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9955 - loss: 0.0846
# Epoch 70: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9955 - loss: 0.0846 - val_accuracy: 0.0080 - val_loss: 127.6206 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 71/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9976 - loss: 0.0717
# Epoch 71: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9976 - loss: 0.0717 - val_accuracy: 0.0208 - val_loss: 28.8990 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 72/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9983 - loss: 0.0687
# Epoch 72: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9983 - loss: 0.0688 - val_accuracy: 0.0092 - val_loss: 102.1859 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 73/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9862 - loss: 0.1120
# Epoch 73: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 0.9861 - loss: 0.1121 - val_accuracy: 0.0067 - val_loss: 193.2565 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 74/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9875 - loss: 0.1112
# Epoch 74: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 0.9875 - loss: 0.1111 - val_accuracy: 0.0325 - val_loss: 83.0748 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 75/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9942 - loss: 0.0883
# Epoch 75: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 330ms/step - accuracy: 0.9942 - loss: 0.0883 - val_accuracy: 0.0061 - val_loss: 118.7162 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 76/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9966 - loss: 0.0774
# Epoch 76: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 331ms/step - accuracy: 0.9966 - loss: 0.0774 - val_accuracy: 0.0129 - val_loss: 237.9986 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 77/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0626
# Epoch 77: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 1.0000 - loss: 0.0626 - val_accuracy: 0.0258 - val_loss: 172.4358 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 78/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0582
# Epoch 78: val_accuracy did not improve from 0.77682
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 1.0000 - loss: 0.0582 - val_accuracy: 0.7652 - val_loss: 1.3651 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 79/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0545
# Epoch 79: val_accuracy improved from 0.77682 to 0.79399, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 1.0000 - loss: 0.0545 - val_accuracy: 0.7940 - val_loss: 1.0684 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 80/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0511
# Epoch 80: val_accuracy did not improve from 0.79399
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 1.0000 - loss: 0.0511 - val_accuracy: 0.7922 - val_loss: 1.0699 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 81/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0479
# Epoch 81: val_accuracy did not improve from 0.79399
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 1.0000 - loss: 0.0479 - val_accuracy: 0.7609 - val_loss: 1.3809 - learning_rate: 0.0010
# Learning rate:  0.0001
# Epoch 82/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0455
# Epoch 82: val_accuracy improved from 0.79399 to 0.81729, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 332ms/step - accuracy: 1.0000 - loss: 0.0455 - val_accuracy: 0.8173 - val_loss: 1.0688 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 83/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0450
# Epoch 83: val_accuracy improved from 0.81729 to 0.81913, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 1.0000 - loss: 0.0450 - val_accuracy: 0.8191 - val_loss: 1.0329 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0447
# Epoch 84: val_accuracy did not improve from 0.81913
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 330ms/step - accuracy: 1.0000 - loss: 0.0447 - val_accuracy: 0.8191 - val_loss: 1.0358 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 85/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0443
# Epoch 85: val_accuracy improved from 0.81913 to 0.82342, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 1.0000 - loss: 0.0443 - val_accuracy: 0.8234 - val_loss: 1.0434 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 86/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0439
# Epoch 86: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 330ms/step - accuracy: 1.0000 - loss: 0.0439 - val_accuracy: 0.8210 - val_loss: 1.0366 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0434
# Epoch 87: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 330ms/step - accuracy: 1.0000 - loss: 0.0434 - val_accuracy: 0.8197 - val_loss: 1.0407 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 88/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 1.0000 - loss: 0.0429
# Epoch 88: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 329ms/step - accuracy: 1.0000 - loss: 0.0429 - val_accuracy: 0.8191 - val_loss: 1.0430 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 89/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0423
# Epoch 89: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 331ms/step - accuracy: 1.0000 - loss: 0.0423 - val_accuracy: 0.8197 - val_loss: 1.0434 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 90/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 1.0000 - loss: 0.0417
# Epoch 90: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 1.0000 - loss: 0.0417 - val_accuracy: 0.8216 - val_loss: 1.0428 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 91/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0411
# Epoch 91: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 331ms/step - accuracy: 1.0000 - loss: 0.0411 - val_accuracy: 0.8228 - val_loss: 1.0538 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 92/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0404
# Epoch 92: val_accuracy improved from 0.82342 to 0.82465, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 331ms/step - accuracy: 1.0000 - loss: 0.0404 - val_accuracy: 0.8246 - val_loss: 1.0500 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 93/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0396
# Epoch 93: val_accuracy did not improve from 0.82465
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 331ms/step - accuracy: 1.0000 - loss: 0.0396 - val_accuracy: 0.8216 - val_loss: 1.0611 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 94/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0388
# Epoch 94: val_accuracy did not improve from 0.82465
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 331ms/step - accuracy: 1.0000 - loss: 0.0388 - val_accuracy: 0.8222 - val_loss: 1.0642 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 95/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 1.0000 - loss: 0.0380
# Epoch 95: val_accuracy did not improve from 0.82465
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 331ms/step - accuracy: 1.0000 - loss: 0.0380 - val_accuracy: 0.8185 - val_loss: 1.0747 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 96/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0371
# Epoch 96: val_accuracy improved from 0.82465 to 0.82526, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 331ms/step - accuracy: 1.0000 - loss: 0.0371 - val_accuracy: 0.8253 - val_loss: 1.0415 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 97/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 1.0000 - loss: 0.0362
# Epoch 97: val_accuracy did not improve from 0.82526
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 329ms/step - accuracy: 1.0000 - loss: 0.0362 - val_accuracy: 0.8234 - val_loss: 1.0557 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 98/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0351
# Epoch 98: val_accuracy did not improve from 0.82526
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 330ms/step - accuracy: 1.0000 - loss: 0.0351 - val_accuracy: 0.8240 - val_loss: 1.0687 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 99/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0341
# Epoch 99: val_accuracy did not improve from 0.82526
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 329ms/step - accuracy: 1.0000 - loss: 0.0341 - val_accuracy: 0.8179 - val_loss: 1.0702 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 100/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 1.0000 - loss: 0.0330
# Epoch 100: val_accuracy did not improve from 0.82526
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 67s 330ms/step - accuracy: 1.0000 - loss: 0.0330 - val_accuracy: 0.8032 - val_loss: 1.1227 - learning_rate: 1.0000e-04

# %%
# Score trained model. 
scores = model.evaluate(x_test, y_test, verbose = 1) 
print('Test loss:', scores[0]) 
print('Test accuracy:', scores[1])
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.8099 - loss: 1.1325
# Test loss: 1.1226773262023926
# Test accuracy: 0.8031882047653198
