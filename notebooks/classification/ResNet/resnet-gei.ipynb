# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import numpy as np
import os

# %%
import pandas as pd
import numpy as np
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

def load_and_preprocess_data(csv_path, image_base_path, angles_to_process=None):
    # Load the metadata CSV
    df = pd.read_csv(csv_path)
    angle_groups = df.groupby('cam_angle')
    
    # If angles_to_process is not specified, process all angles
    if angles_to_process is None:
        angles_to_process = angle_groups.groups.keys()
    else:
        angles_to_process = [angles_to_process] if isinstance(angles_to_process, (int, float)) else angles_to_process
    
    X_all, y_all = [], []
    
    # Iterate through each angle and process
    for angle in angles_to_process:
        if angle not in angle_groups.groups:
            print(f"Angle {angle} not found in the dataset. Skipping.")
            continue
        print(f"Processing angle: {angle}")
        group = angle_groups.get_group(angle)
        
        for _, row in group.iterrows():
            image_path = os.path.join(image_base_path, row['image_filename'])
            try:
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    img = cv2.resize(img, (240, 240))
                    img = img.astype('float32') / 255.0  # Normalize to [0, 1]
                    X_all.append(img)
                    y_all.append(row['label'])
                else:
                    print(f"Failed to load image: {image_path}")
            except Exception as e:
                print(f"Error processing image {image_path}: {str(e)}")
    
    if not X_all:
        raise ValueError("No valid images found in the dataset.")
    
    X_all = np.array(X_all)
    y_all = np.array(y_all)
    
    # Use LabelEncoder to ensure labels are zero-indexed
    label_encoder = LabelEncoder()
    y_all = label_encoder.fit_transform(y_all)
    
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=42)
    
    # Reshape the data to match the CIFAR-10 format
    X_train = X_train.reshape(-1, 240, 240, 1)
    X_test = X_test.reshape(-1, 240, 240, 1)
    
    # Get the number of unique classes
    num_classes = len(label_encoder.classes_)
    
    return (X_train, y_train), (X_test, y_test), num_classes

def load_data():
    # Define the paths
    csv_path = '/kaggle/input/processed-msi-dataset/msi_metadata.csv'
    image_base_path = '/kaggle/input/processed-msi-dataset/msi_images'
    
    # Specify the angles to process
    angles_to_process = [0, 18, 36, 54, 72, 90, 108, 126, 144, 162, 180]
    
    # Load and preprocess the data
    return load_and_preprocess_data(csv_path, image_base_path, angles_to_process)

# Usage example:
(X_train, y_train), (X_test, y_test), num_classes = load_data()

# Print summary of the loaded data
print("\nSummary of loaded data:")
print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")
print(f"Image shape: {X_train.shape[1:]}")
print(f"Number of classes: {num_classes}")

# Data Preprocessing
subtract_pixel_mean = True

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(X_train, axis=0)
    X_train -= x_train_mean
    X_test -= x_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes) 
y_test = keras.utils.to_categorical(y_test, num_classes)

# Print shapes after preprocessing
print("\nAfter preprocessing:")
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# Processing angle: 0
# Processing angle: 18
# Processing angle: 36
# Processing angle: 54
# Processing angle: 72
# Processing angle: 90
# Processing angle: 108
# Processing angle: 126
# Processing angle: 144
# Processing angle: 162
# Processing angle: 180
#
# Summary of loaded data:
# Training samples: 6523
# Testing samples: 1631
# Image shape: (240, 240, 1)
# Number of classes: 124
#
# After preprocessing:
# X_train shape: (6523, 240, 240, 1)
# 6523 train samples
# 1631 test samples
# y_train shape: (6523, 124)

# %%
# Setting LR for different number of Epochs 
def lr_schedule(epoch): 
	lr = 1e-3
	if epoch > 180: 
		lr *= 0.5e-3
	elif epoch > 160: 
		lr *= 1e-3
	elif epoch > 120: 
		lr *= 1e-2
	elif epoch > 80: 
		lr *= 1e-1
	print('Learning rate: ', lr) 
	return lr

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation
from tensorflow.keras.regularizers import l2

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    Args:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or bn-activation-conv (False)

    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Activation, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def resnet_v1(input_shape, depth, num_classes=10):
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])')
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Activation, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def resnet_v1(input_shape, depth, num_classes=124):  # Changed default to 124
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])')
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Create the model
input_shape = X_train.shape[1:]  # Assuming x_train is your input data
depth = 20  # or whatever depth you're using
model = resnet_v1(input_shape=input_shape, depth=depth, num_classes=124)

# Print model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 240, 240,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 240, 240,  │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 240, 240,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_1[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 240, 240,  │          0 │ activation[0][0], │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 240, 240,  │          0 │ add[0][0]         │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_2[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_3[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 240, 240,  │          0 │ activation_2[0][… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 240, 240,  │          0 │ add_1[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_4[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 240, 240,  │      2,320 │ activation_5[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 240, 240,  │          0 │ activation_4[0][… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 240, 240,  │          0 │ add_2[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 120, 120,  │      4,640 │ activation_6[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 120, 120,  │      9,248 │ activation_7[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 120, 120,  │        544 │ activation_6[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 120, 120,  │          0 │ conv2d_9[0][0],   │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 120, 120,  │          0 │ add_3[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_8[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_9[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 120, 120,  │          0 │ activation_8[0][… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 120, 120,  │          0 │ add_4[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_10[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_11[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 120, 120,  │          0 │ activation_10[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 120, 120,  │          0 │ add_5[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 60, 60,    │     18,496 │ activation_12[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_13[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 60, 60,    │      2,112 │ activation_12[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 60, 60,    │          0 │ conv2d_16[0][0],  │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 60, 60,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_14[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_15[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 60, 60,    │          0 │ activation_14[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 60, 60,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_17[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 60, 60,    │          0 │ activation_16[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 60, 60,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 7, 7, 64)  │          0 │ activation_18[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3136)      │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 124)       │    388,988 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 662,492 (2.53 MB)
#  Trainable params: 661,116 (2.52 MB)
#  Non-trainable params: 1,376 (5.38 KB)

# %%
import os
import numpy as np
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau

# Learning rate schedule
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Set up model name and save directory
version = 1  # Assuming you're using version 1
depth = 20  # Assuming you're using depth 20
model_type = f'ResNet{depth}v{version}'
model_name = f'msi_{model_type}_model.keras'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment
checkpoint = ModelCheckpoint(
    filepath=filepath,
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(
    factor=np.sqrt(0.1),
    cooldown=0,
    patience=5,
    min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Compile model
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])

# Run training
batch_size = 32  # Adjust as needed
epochs = 100     # Adjust as needed

history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(X_test, y_test),
                    shuffle=True,
                    callbacks=callbacks)
# Out:
# Learning rate:  0.001
# Learning rate:  0.001
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727401279.190777     116 service.cc:145] XLA service 0x7bf930019bf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727401279.190841     116 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1727401279.190847     116 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1727401297.637097     116 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.0162 - loss: 6.6043
# Epoch 1: val_accuracy improved from -inf to 0.00858, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 115s 402ms/step - accuracy: 0.0162 - loss: 6.5981 - val_accuracy: 0.0086 - val_loss: 4.9779 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.1281 - loss: 4.0265
# Epoch 2: val_accuracy improved from 0.00858 to 0.13611, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 66s 322ms/step - accuracy: 0.1282 - loss: 4.0256 - val_accuracy: 0.1361 - val_loss: 3.9251 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 3/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.2945 - loss: 3.0758
# Epoch 3: val_accuracy improved from 0.13611 to 0.17167, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 321ms/step - accuracy: 0.2946 - loss: 3.0752 - val_accuracy: 0.1717 - val_loss: 3.7822 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 4/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.4550 - loss: 2.2531
# Epoch 4: val_accuracy improved from 0.17167 to 0.22379, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 66s 321ms/step - accuracy: 0.4550 - loss: 2.2528 - val_accuracy: 0.2238 - val_loss: 4.4947 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 5/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.6165 - loss: 1.5767
# Epoch 5: val_accuracy did not improve from 0.22379
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 321ms/step - accuracy: 0.6166 - loss: 1.5766 - val_accuracy: 0.1729 - val_loss: 8.4368 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 6/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.7331 - loss: 1.1034
# Epoch 6: val_accuracy improved from 0.22379 to 0.35377, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 66s 322ms/step - accuracy: 0.7330 - loss: 1.1034 - val_accuracy: 0.3538 - val_loss: 3.6454 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 7/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8057 - loss: 0.8411
# Epoch 7: val_accuracy improved from 0.35377 to 0.43532, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 66s 322ms/step - accuracy: 0.8057 - loss: 0.8411 - val_accuracy: 0.4353 - val_loss: 2.9387 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 8/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8658 - loss: 0.6187
# Epoch 8: val_accuracy improved from 0.43532 to 0.46597, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 66s 321ms/step - accuracy: 0.8658 - loss: 0.6188 - val_accuracy: 0.4660 - val_loss: 3.1300 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 9/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9059 - loss: 0.4736
# Epoch 9: val_accuracy improved from 0.46597 to 0.50521, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 66s 322ms/step - accuracy: 0.9058 - loss: 0.4737 - val_accuracy: 0.5052 - val_loss: 2.4626 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 10/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9343 - loss: 0.3833
# Epoch 10: val_accuracy improved from 0.50521 to 0.57265, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 66s 321ms/step - accuracy: 0.9342 - loss: 0.3834 - val_accuracy: 0.5727 - val_loss: 1.8293 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 11/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9402 - loss: 0.3427
# Epoch 11: val_accuracy did not improve from 0.57265
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 320ms/step - accuracy: 0.9402 - loss: 0.3427 - val_accuracy: 0.5671 - val_loss: 2.2593 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 12/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9496 - loss: 0.3042
# Epoch 12: val_accuracy improved from 0.57265 to 0.69712, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 66s 322ms/step - accuracy: 0.9496 - loss: 0.3042 - val_accuracy: 0.6971 - val_loss: 1.4197 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 13/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9724 - loss: 0.2511
# Epoch 13: val_accuracy did not improve from 0.69712
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 320ms/step - accuracy: 0.9724 - loss: 0.2511 - val_accuracy: 0.6407 - val_loss: 2.0316 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 14/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9600 - loss: 0.2805
# Epoch 14: val_accuracy did not improve from 0.69712
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 82s 322ms/step - accuracy: 0.9600 - loss: 0.2804 - val_accuracy: 0.4960 - val_loss: 3.2418 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 15/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9499 - loss: 0.3112
# Epoch 15: val_accuracy did not improve from 0.69712
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 319ms/step - accuracy: 0.9499 - loss: 0.3112 - val_accuracy: 0.6107 - val_loss: 2.3375 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 16/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9716 - loss: 0.2345
# Epoch 16: val_accuracy improved from 0.69712 to 0.75536, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 321ms/step - accuracy: 0.9717 - loss: 0.2344 - val_accuracy: 0.7554 - val_loss: 1.1453 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 17/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9857 - loss: 0.1869
# Epoch 17: val_accuracy did not improve from 0.75536
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 320ms/step - accuracy: 0.9856 - loss: 0.1869 - val_accuracy: 0.7149 - val_loss: 1.3550 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 18/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9782 - loss: 0.2160
# Epoch 18: val_accuracy did not improve from 0.75536
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 321ms/step - accuracy: 0.9782 - loss: 0.2161 - val_accuracy: 0.6334 - val_loss: 2.1826 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 19/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9836 - loss: 0.1954
# Epoch 19: val_accuracy did not improve from 0.75536
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 320ms/step - accuracy: 0.9836 - loss: 0.1954 - val_accuracy: 0.6530 - val_loss: 1.8814 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 20/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9731 - loss: 0.2288
# Epoch 20: val_accuracy did not improve from 0.75536
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 82s 321ms/step - accuracy: 0.9730 - loss: 0.2289 - val_accuracy: 0.6113 - val_loss: 2.4274 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 21/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9686 - loss: 0.2361
# Epoch 21: val_accuracy did not improve from 0.75536
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 319ms/step - accuracy: 0.9686 - loss: 0.2360 - val_accuracy: 0.6536 - val_loss: 1.8097 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 22/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9836 - loss: 0.1822
# Epoch 22: val_accuracy did not improve from 0.75536
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 320ms/step - accuracy: 0.9835 - loss: 0.1823 - val_accuracy: 0.7100 - val_loss: 1.4638 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 23/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.
val_accuracy did not improve from 0.82219
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 319ms/step - accuracy: 1.0000 - loss: 0.0459 - val_accuracy: 0.8210 - val_loss: 0.9024 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 73/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0432
# Epoch 73: val_accuracy did not improve from 0.82219
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 319ms/step - accuracy: 1.0000 - loss: 0.0432 - val_accuracy: 0.8179 - val_loss: 0.9233 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 74/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0405
# Epoch 74: val_accuracy improved from 0.82219 to 0.82342, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 320ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.8234 - val_loss: 0.8887 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 75/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 1.0000 - loss: 0.0380
# Epoch 75: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 319ms/step - accuracy: 1.0000 - loss: 0.0380 - val_accuracy: 0.8161 - val_loss: 0.9446 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 76/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0355
# Epoch 76: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 319ms/step - accuracy: 1.0000 - loss: 0.0355 - val_accuracy: 0.8216 - val_loss: 0.9346 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 77/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0330
# Epoch 77: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 319ms/step - accuracy: 1.0000 - loss: 0.0330 - val_accuracy: 0.8222 - val_loss: 0.9381 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 78/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0306
# Epoch 78: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 319ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 0.8185 - val_loss: 0.9909 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 79/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0283
# Epoch 79: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0283 - val_accuracy: 0.8124 - val_loss: 1.0128 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 80/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9892 - loss: 0.0701
# Epoch 80: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 0.9889 - loss: 0.0710 - val_accuracy: 0.1471 - val_loss: 23.6119 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 81/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9551 - loss: 0.2063
# Epoch 81: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 0.9551 - loss: 0.2062 - val_accuracy: 0.6763 - val_loss: 2.0456 - learning_rate: 0.0010
# Learning rate:  0.0001
# Epoch 82/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9928 - loss: 0.0799
# Epoch 82: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 0.9928 - loss: 0.0799 - val_accuracy: 0.8063 - val_loss: 0.9199 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 83/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0570
# Epoch 83: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0570 - val_accuracy: 0.8093 - val_loss: 0.8917 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0545
# Epoch 84: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0545 - val_accuracy: 0.8118 - val_loss: 0.8912 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 85/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0537
# Epoch 85: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0537 - val_accuracy: 0.8136 - val_loss: 0.8770 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 86/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0540
# Epoch 86: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0540 - val_accuracy: 0.8142 - val_loss: 0.8884 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0513
# Epoch 87: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0513 - val_accuracy: 0.8130 - val_loss: 0.8799 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 88/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0513
# Epoch 88: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0513 - val_accuracy: 0.8130 - val_loss: 0.8755 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 89/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0500
# Epoch 89: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0500 - val_accuracy: 0.8142 - val_loss: 0.8797 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 90/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0490
# Epoch 90: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0490 - val_accuracy: 0.8124 - val_loss: 0.8799 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 91/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0486
# Epoch 91: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0486 - val_accuracy: 0.8136 - val_loss: 0.8851 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 92/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0473
# Epoch 92: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0473 - val_accuracy: 0.8130 - val_loss: 0.8861 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 93/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0465
# Epoch 93: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0465 - val_accuracy: 0.8136 - val_loss: 0.8908 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 94/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0460
# Epoch 94: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0460 - val_accuracy: 0.8118 - val_loss: 0.8915 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 95/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0449
# Epoch 95: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0449 - val_accuracy: 0.8124 - val_loss: 0.8928 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 96/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0439
# Epoch 96: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0439 - val_accuracy: 0.8161 - val_loss: 0.8857 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 97/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0433
# Epoch 97: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0433 - val_accuracy: 0.8167 - val_loss: 0.8984 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 98/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0424
# Epoch 98: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0424 - val_accuracy: 0.8167 - val_loss: 0.9081 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 99/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0413
# Epoch 99: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0413 - val_accuracy: 0.8167 - val_loss: 0.9021 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 100/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 1.0000 - loss: 0.0404
# Epoch 100: val_accuracy did not improve from 0.82342
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 65s 318ms/step - accuracy: 1.0000 - loss: 0.0404 - val_accuracy: 0.8142 - val_loss: 0.9094 - learning_rate: 1.0000e-04

# %%
# Score trained model. 
scores = model.evaluate(X_test, y_test, verbose = 1) 
print('Test loss:', scores[0]) 
print('Test accuracy:', scores[1])
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8236 - loss: 0.8625
# Test loss: 0.909403920173645
# Test accuracy: 0.8142244219779968
