# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import numpy as np
import os

# %%
import pandas as pd
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

def load_and_preprocess_data(csv_path, image_base_path, angles_to_process=None):
    # Load the metadata CSV
    df = pd.read_csv(csv_path)
    angle_groups = df.groupby('cam_angle')
    
    # If angles_to_process is not specified, process all angles
    if angles_to_process is None:
        angles_to_process = angle_groups.groups.keys()
    else:
        angles_to_process = [angles_to_process] if isinstance(angles_to_process, (int, float)) else angles_to_process
    
    X_all, y_all = [], []
    
    # Iterate through each angle and process
    for angle in angles_to_process:
        if angle not in angle_groups.groups:
            print(f"Angle {angle} not found in the dataset. Skipping.")
            continue
        print(f"Processing angle: {angle}")
        group = angle_groups.get_group(angle)
        
        for _, row in group.iterrows():
            image_path = os.path.join(image_base_path, row['image_filename'])
            try:
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    img = cv2.resize(img, (240, 240))
                    img = img.astype('float32') / 255.0  # Normalize to [0, 1]
                    X_all.append(img)
                    y_all.append(row['label'])
                else:
                    print(f"Failed to load image: {image_path}")
            except Exception as e:
                print(f"Error processing image {image_path}: {str(e)}")
    
    if not X_all:
        raise ValueError("No valid images found in the dataset.")
    
    X_all = np.array(X_all)
    y_all = np.array(y_all)
    
    # Use LabelEncoder to ensure labels are zero-indexed
    label_encoder = LabelEncoder()
    y_all = label_encoder.fit_transform(y_all)
    
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=42)
    
    # Reshape the data to match the CIFAR-10 format
    X_train = X_train.reshape(-1, 240, 240, 1)
    X_test = X_test.reshape(-1, 240, 240, 1)
    
    # Get the number of unique classes
    num_classes = len(label_encoder.classes_)
    
    return (X_train, y_train), (X_test, y_test), num_classes

def load_data():
    # Define the paths
    csv_path = '/kaggle/input/gei-lbp1/gei_lbp_metadata.csv'
    image_base_path = '/kaggle/input/gei-lbp1/gei_lbp_images'
    
    # Specify the angles to process
    angles_to_process = [0, 18, 36, 54, 72, 90, 108, 126, 144, 162, 180]
    
    # Load and preprocess the data
    return load_and_preprocess_data(csv_path, image_base_path, angles_to_process)

# Usage example:
(X_train, y_train), (X_test, y_test), num_classes = load_data()

# Print summary of the loaded data
print("\nSummary of loaded data:")
print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")
print(f"Image shape: {X_train.shape[1:]}")
print(f"Number of classes: {num_classes}")

# Data Preprocessing
subtract_pixel_mean = True

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(X_train, axis=0)
    X_train -= x_train_mean
    X_test -= x_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes) 
y_test = keras.utils.to_categorical(y_test, num_classes)

# Print shapes after preprocessing
print("\nAfter preprocessing:")
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# Processing angle: 0
# Processing angle: 18
# Processing angle: 36
# Processing angle: 54
# Processing angle: 72
# Processing angle: 90
# Processing angle: 108
# Processing angle: 126
# Processing angle: 144
# Processing angle: 162
# Processing angle: 180
#
# Summary of loaded data:
# Training samples: 6524
# Testing samples: 1631
# Image shape: (240, 240, 1)
# Number of classes: 124
#
# After preprocessing:
# X_train shape: (6524, 240, 240, 1)
# 6524 train samples
# 1631 test samples
# y_train shape: (6524, 124)

# %%
# Setting LR for different number of Epochs 
def lr_schedule(epoch): 
	lr = 1e-3
	if epoch > 180: 
		lr *= 0.5e-3
	elif epoch > 160: 
		lr *= 1e-3
	elif epoch > 120: 
		lr *= 1e-2
	elif epoch > 80: 
		lr *= 1e-1
	print('Learning rate: ', lr) 
	return lr

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation
from tensorflow.keras.regularizers import l2

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    Args:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or bn-activation-conv (False)

    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Activation, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def resnet_v1(input_shape, depth, num_classes=10):
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])')
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Activation, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def resnet_v1(input_shape, depth, num_classes=124):  # Changed default to 124
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])')
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Create the model
input_shape = X_train.shape[1:]  # Assuming x_train is your input data
depth = 20  # or whatever depth you're using
model = resnet_v1(input_shape=input_shape, depth=depth, num_classes=124)

# Print model summary
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 240, 240,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 240, 240,  │        160 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_19[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_20[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 240, 240,  │          0 │ activation_19[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 240, 240,  │          0 │ add_9[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_21[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_22[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 240, 240,  │          0 │ activation_21[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 240, 240,  │          0 │ add_10[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_23[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 240, 240,  │      2,320 │ activation_24[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │         64 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 240, 240,  │          0 │ activation_23[0]… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 240, 240,  │          0 │ add_11[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 120, 120,  │      4,640 │ activation_25[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_26[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 120, 120,  │        544 │ activation_25[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 120, 120,  │          0 │ conv2d_30[0][0],  │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 120, 120,  │          0 │ add_12[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_27[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_28[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 120, 120,  │          0 │ activation_27[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 120, 120,  │          0 │ add_13[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_29[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 120, 120,  │      9,248 │ activation_30[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        128 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 120, 120,  │          0 │ activation_29[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 120, 120,  │          0 │ add_14[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 60, 60,    │     18,496 │ activation_31[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_32[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 60, 60,    │      2,112 │ activation_31[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 60, 60,    │          0 │ conv2d_37[0][0],  │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 60, 60,    │          0 │ add_15[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_33[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_34[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 60, 60,    │          0 │ activation_33[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 60, 60,    │          0 │ add_16[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_35[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 60, 60,    │     36,928 │ activation_36[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        256 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 60, 60,    │          0 │ activation_35[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 60, 60,    │          0 │ add_17[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 7, 7, 64)  │          0 │ activation_37[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 3136)      │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 124)       │    388,988 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 662,492 (2.53 MB)
#  Trainable params: 661,116 (2.52 MB)
#  Non-trainable params: 1,376 (5.38 KB)

# %%
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau

# Learning rate schedule
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Set up model name and save directory
version = 1  # Assuming you're using version 1
depth = 20  # Assuming you're using depth 20
model_type = f'ResNet{depth}v{version}'
model_name = f'msi_{model_type}_model.keras'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment
checkpoint = ModelCheckpoint(
    filepath=filepath,
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(
    factor=np.sqrt(0.1),
    cooldown=0,
    patience=5,
    min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Compile model
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])

# Run training
batch_size = 32  # Adjust as needed
epochs = 100     # Adjust as needed

history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(X_test, y_test),
                    shuffle=True,
                    callbacks=callbacks)
# Out:
# Learning rate:  0.001
# Learning rate:  0.001
# Epoch 1/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.0154 - loss: 6.9757
# Epoch 1: val_accuracy improved from -inf to 0.00858, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 95s 384ms/step - accuracy: 0.0155 - loss: 6.9688 - val_accuracy: 0.0086 - val_loss: 5.0669 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.0845 - loss: 4.2842
# Epoch 2: val_accuracy did not improve from 0.00858
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.0846 - loss: 4.2832 - val_accuracy: 0.0049 - val_loss: 8.8347 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 3/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.2572 - loss: 3.1960
# Epoch 3: val_accuracy improved from 0.00858 to 0.14715, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.2574 - loss: 3.1949 - val_accuracy: 0.1471 - val_loss: 4.8959 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 4/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.4826 - loss: 2.1741
# Epoch 4: val_accuracy improved from 0.14715 to 0.32373, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.4827 - loss: 2.1737 - val_accuracy: 0.3237 - val_loss: 3.2848 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 5/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.6591 - loss: 1.4235
# Epoch 5: val_accuracy did not improve from 0.32373
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.6591 - loss: 1.4237 - val_accuracy: 0.2722 - val_loss: 3.2461 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 6/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7161 - loss: 1.1606
# Epoch 6: val_accuracy improved from 0.32373 to 0.50337, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 341ms/step - accuracy: 0.7162 - loss: 1.1602 - val_accuracy: 0.5034 - val_loss: 2.3061 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 7/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8213 - loss: 0.7879
# Epoch 7: val_accuracy did not improve from 0.50337
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.8213 - loss: 0.7881 - val_accuracy: 0.4102 - val_loss: 3.0298 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 8/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8795 - loss: 0.5957
# Epoch 8: val_accuracy improved from 0.50337 to 0.52238, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.8794 - loss: 0.5959 - val_accuracy: 0.5224 - val_loss: 2.2135 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 9/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8835 - loss: 0.5780
# Epoch 9: val_accuracy improved from 0.52238 to 0.59105, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.8836 - loss: 0.5778 - val_accuracy: 0.5910 - val_loss: 2.1522 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 10/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9349 - loss: 0.3920
# Epoch 10: val_accuracy did not improve from 0.59105
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9348 - loss: 0.3920 - val_accuracy: 0.5408 - val_loss: 2.1303 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 11/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9410 - loss: 0.3513
# Epoch 11: val_accuracy did not improve from 0.59105
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9411 - loss: 0.3511 - val_accuracy: 0.5635 - val_loss: 2.0863 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 12/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9618 - loss: 0.2906
# Epoch 12: val_accuracy did not improve from 0.59105
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9618 - loss: 0.2907 - val_accuracy: 0.4427 - val_loss: 2.9812 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 13/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9464 - loss: 0.3287
# Epoch 13: val_accuracy did not improve from 0.59105
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9464 - loss: 0.3288 - val_accuracy: 0.5610 - val_loss: 1.8732 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 14/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9680 - loss: 0.2544
# Epoch 14: val_accuracy did not improve from 0.59105
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 341ms/step - accuracy: 0.9680 - loss: 0.2544 - val_accuracy: 0.2918 - val_loss: 5.2669 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 15/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9800 - loss: 0.2185
# Epoch 15: val_accuracy improved from 0.59105 to 0.67259, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9800 - loss: 0.2186 - val_accuracy: 0.6726 - val_loss: 1.6097 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 16/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9477 - loss: 0.3009
# Epoch 16: val_accuracy did not improve from 0.67259
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9477 - loss: 0.3009 - val_accuracy: 0.5377 - val_loss: 2.7883 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 17/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9736 - loss: 0.2216
# Epoch 17: val_accuracy did not improve from 0.67259
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9736 - loss: 0.2217 - val_accuracy: 0.4237 - val_loss: 3.6602 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 18/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9797 - loss: 0.2118
# Epoch 18: val_accuracy did not improve from 0.67259
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 338ms/step - accuracy: 0.9797 - loss: 0.2118 - val_accuracy: 0.5714 - val_loss: 2.7485 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 19/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9857 - loss: 0.1872
# Epoch 19: val_accuracy did not improve from 0.67259
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 338ms/step - accuracy: 0.9856 - loss: 0.1873 - val_accuracy: 0.3250 - val_loss: 6.7425 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 20/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9694 - loss: 0.2235
# Epoch 20: val_accuracy did not improve from 0.67259
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 338ms/step - accuracy: 0.9694 - loss: 0.2235 - val_accuracy: 0.5861 - val_loss: 2.1362 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 21/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9720 - loss: 0.2276
# Epoch 21: val_accuracy improved from 0.67259 to 0.67566, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9720 - loss: 0.2277 - val_accuracy: 0.6757 - val_loss: 1.6503 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 22/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9855 - loss: 0.1787
# Epoch 22: val_accuracy did not improve from 0.67566
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9855 - loss: 0.1787 - val_accuracy: 0.5855 - val_loss: 2.3559 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 23/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9805 - loss: 0.1866
# Epoch 23: val_accuracy did not improve from 0.67566
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9804 - loss: 0.1867 - val_accuracy: 0.5414 - val_loss: 2.6577 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 24/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9706 - loss: 0.2140
# Epoch 24: val_accuracy did not improve from 0.67566
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9707 - loss: 0.2139 - val_accuracy: 0.5003 - val_loss: 3.5069 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 25/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9870 - loss: 0.1616
# Epoch 25: val_accuracy did not improve from 0.67566
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 342ms/step - accuracy: 0.9870 - loss: 0.1616 - val_accuracy: 0.5236 - val_loss: 2.9096 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 26/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9859 - loss: 0.1703
# Epoch 26: val_accuracy did not improve from 0.67566
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 341ms/step - accuracy: 0.9859 - loss: 0.1703 - val_accuracy: 0.5892 - val_loss: 2.3220 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 27/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9848 - loss: 0.1607
# Epoch 27: val_accuracy improved from 0.67566 to 0.67872, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9848 - loss: 0.1607 - val_accuracy: 0.6787 - val_loss: 1.4816 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 28/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9895 - loss: 0.1608
# Epoch 28: val_accuracy did not improve from 0.67872
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9895 - loss: 0.1608 - val_accuracy: 0.6235 - val_loss: 1.9588 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 29/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9907 - loss: 0.1443
# Epoch 29: val_accuracy did not improve from 0.67872
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9906 - loss: 0.1446 - val_accuracy: 0.1944 - val_loss: 19.1200 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 30/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9523 - loss: 0.2727
# Epoch 30: val_accuracy did not improve from 0.67872
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 341ms/step - accuracy: 0.9524 - loss: 0.2726 - val_accuracy: 0.6242 - val_loss: 2.4358 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 31/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9856 - loss: 0.1680
# Epoch 31: val_accuracy improved from 0.67872 to 0.73697, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 70s 341ms/step - accuracy: 0.9856 - loss: 0.1679 - val_accuracy: 0.7370 - val_loss: 1.1795 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 32/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9942 - loss: 0.1268
# Epoch 32: val_accuracy improved from 0.73697 to 0.75598, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9942 - loss: 0.1268 - val_accuracy: 0.7560 - val_loss: 1.3532 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 33/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9953 - loss: 0.1243
# Epoch 33: val_accuracy improved from 0.75598 to 0.76947, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9953 - loss: 0.1243 - val_accuracy: 0.7695 - val_loss: 1.1142 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 34/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9973 - loss: 0.1097
# Epoch 34: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9973 - loss: 0.1098 - val_accuracy: 0.1625 - val_loss: 23.4905 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 35/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9740 - loss: 0.1841
# Epoch 35: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9740 - loss: 0.1841 - val_accuracy: 0.4721 - val_loss: 3.7916 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 36/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9812 - loss: 0.1650
# Epoch 36: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9812 - loss: 0.1649 - val_accuracy: 0.6235 - val_loss: 1.8850 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 37/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9840 - loss: 0.1490
# Epoch 37: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 338ms/step - accuracy: 0.9840 - loss: 0.1491 - val_accuracy: 0.5469 - val_loss: 2.9655 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 38/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9852 - loss: 0.1525
# Epoch 38: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9852 - loss: 0.1525 - val_accuracy: 0.1465 - val_loss: 14.0653 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 39/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9702 - loss: 0.1996
# Epoch 39: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9702 - loss: 0.1996 - val_accuracy: 0.5855 - val_loss: 2.8489 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 40/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9816 - loss: 0.1663
# Epoch 40: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9816 - loss: 0.1662 - val_accuracy: 0.6898 - val_loss: 1.7754 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 41/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9957 - loss: 0.1081
# Epoch 41: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9957 - loss: 0.1081 - val_accuracy: 0.6113 - val_loss: 2.4352 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 42/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9920 - loss: 0.1286
# Epoch 42: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 340ms/step - accuracy: 0.9920 - loss: 0.1286 - val_accuracy: 0.4580 - val_loss: 4.6088 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 43/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9961 - loss: 0.1099
# Epoch 43: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9961 - loss: 0.1099 - val_accuracy: 0.7143 - val_loss: 1.5666 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 44/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9948 - loss: 0.1049
# Epoch 44: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9947 - loss: 0.1049 - val_accuracy: 0.5708 - val_loss: 2.7744 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 45/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9924 - loss: 0.1121
# Epoch 45: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9924 - loss: 0.1121 - val_accuracy: 0.4586 - val_loss: 4.1737 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 46/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9817 - loss: 0.1638
# Epoch 46: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9817 - loss: 0.1637 - val_accuracy: 0.6640 - val_loss: 1.6126 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 47/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9910 - loss: 0.1177
# Epoch 47: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 338ms/step - accuracy: 0.9910 - loss: 0.1177 - val_accuracy: 0.7639 - val_loss: 1.2765 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 48/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9917 - loss: 0.1106
# Epoch 48: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9916 - loss: 0.1107 - val_accuracy: 0.6536 - val_loss: 1.8024 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 49/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9825 - loss: 0.1423
# Epoch 49: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9825 - loss: 0.1423 - val_accuracy: 0.6266 - val_loss: 2.1054 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 50/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9934 - loss: 0.1033
# Epoch 50: val_accuracy did not improve from 0.76947
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9935 - loss: 0.1033 - val_accuracy: 0.6383 - val_loss: 1.9515 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 51/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9978 - loss: 0.0846
# Epoch 51: val_accuracy improved from 0.76947 to 0.79154, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 339ms/step - accuracy: 0.9978 - loss: 0.0846 - val_accuracy: 0.7915 - val_loss: 0.9856 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 52/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9995 - loss: 0.0759
# Epoch 52: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9995 - loss: 0.0759 - val_accuracy: 0.2630 - val_loss: 8.4294 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 53/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9800 - loss: 0.1389
# Epoch 53: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9800 - loss: 0.1392 - val_accuracy: 0.2594 - val_loss: 10.5758 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 54/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9829 - loss: 0.1446
# Epoch 54: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9829 - loss: 0.1445 - val_accuracy: 0.3691 - val_loss: 6.4260 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 55/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9964 - loss: 0.0907
# Epoch 55: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9964 - loss: 0.0907 - val_accuracy: 0.7511 - val_loss: 1.1695 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 56/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9971 - loss: 0.0860
# Epoch 56: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9971 - loss: 0.0860 - val_accuracy: 0.6284 - val_loss: 2.0633 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 57/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9977 - loss: 0.0783
# Epoch 57: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9977 - loss: 0.0783 - val_accuracy: 0.6806 - val_loss: 1.9656 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 58/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9777 - loss: 0.1424
# Epoch 58: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9777 - loss: 0.1425 - val_accuracy: 0.5622 - val_loss: 2.8589 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 59/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9864 - loss: 0.1280
# Epoch 59: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9864 - loss: 0.1279 - val_accuracy: 0.6861 - val_loss: 1.6390 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 60/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9956 - loss: 0.0915
# Epoch 60: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9957 - loss: 0.0915 - val_accuracy: 0.6953 - val_loss: 1.6805 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 61/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9906 - loss: 0.1070
# Epoch 61: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 338ms/step - accuracy: 0.9906 - loss: 0.1070 - val_accuracy: 0.4243 - val_loss: 4.0714 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 62/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9962 - loss: 0.0845
# Epoch 62: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9962 - loss: 0.0845 - val_accuracy: 0.6517 - val_loss: 2.5940 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 63/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9928 - loss: 0.0927
# Epoch 63: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9927 - loss: 0.0928 - val_accuracy: 0.4114 - val_loss: 7.8924 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 64/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9852 - loss: 0.1206
# Epoch 64: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9853 - loss: 0.1205 - val_accuracy: 0.6052 - val_loss: 2.0826 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 65/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9931 - loss: 0.0996
# Epoch 65: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9931 - loss: 0.0996 - val_accuracy: 0.5812 - val_loss: 2.7727 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 66/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9965 - loss: 0.0849
# Epoch 66: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9965 - loss: 0.0849 - val_accuracy: 0.5487 - val_loss: 3.1283 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 67/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9951 - loss: 0.0806
# Epoch 67: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 83s 340ms/step - accuracy: 0.9951 - loss: 0.0806 - val_accuracy: 0.3887 - val_loss: 7.1523 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 68/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9965 - loss: 0.0769
# Epoch 68: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 336ms/step - accuracy: 0.9964 - loss: 0.0770 - val_accuracy: 0.4758 - val_loss: 3.2598 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 69/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9862 - loss: 0.1179
# Epoch 69: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9862 - loss: 0.1179 - val_accuracy: 0.2692 - val_loss: 12.6140 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 70/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9924 - loss: 0.0988
# Epoch 70: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9924 - loss: 0.0988 - val_accuracy: 0.5340 - val_loss: 3.6817 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 71/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9969 - loss: 0.0803
# Epoch 71: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 0.9969 - loss: 0.0803 - val_accuracy: 0.5843 - val_loss: 3.1753 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 72/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9944 - loss: 0.0819
# Epoch 72: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9943 - loss: 0.0820 - val_accuracy: 0.6567 - val_loss: 2.0564 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 73/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9881 - loss: 0.1004
# Epoch 73: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9881 - loss: 0.1004 - val_accuracy: 0.6407 - val_loss: 2.5047 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 74/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9933 - loss: 0.0865
# Epoch 74: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9933 - loss: 0.0864 - val_accuracy: 0.4788 - val_loss: 4.0794 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 75/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9966 - loss: 0.0756
# Epoch 75: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9966 - loss: 0.0756 - val_accuracy: 0.7400 - val_loss: 1.4409 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 76/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9891 - loss: 0.0957
# Epoch 76: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9891 - loss: 0.0957 - val_accuracy: 0.2735 - val_loss: 12.4333 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 77/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9886 - loss: 0.1050
# Epoch 77: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 336ms/step - accuracy: 0.9886 - loss: 0.1049 - val_accuracy: 0.7707 - val_loss: 1.2897 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 78/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9957 - loss: 0.0736
# Epoch 78: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9956 - loss: 0.0736 - val_accuracy: 0.5929 - val_loss: 2.4990 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 79/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9941 - loss: 0.0830
# Epoch 79: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 336ms/step - accuracy: 0.9940 - loss: 0.0831 - val_accuracy: 0.6346 - val_loss: 2.5630 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 80/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9899 - loss: 0.0998
# Epoch 80: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9899 - loss: 0.0997 - val_accuracy: 0.4543 - val_loss: 4.9629 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 81/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9926 - loss: 0.0850
# Epoch 81: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 336ms/step - accuracy: 0.9926 - loss: 0.0850 - val_accuracy: 0.2042 - val_loss: 11.4541 - learning_rate: 3.1623e-04
# Learning rate:  0.0001
# Epoch 82/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9971 - loss: 0.0702
# Epoch 82: val_accuracy did not improve from 0.79154
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 336ms/step - accuracy: 0.9971 - loss: 0.0702 - val_accuracy: 0.7879 - val_loss: 1.0941 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 83/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9999 - loss: 0.0616
# Epoch 83: val_accuracy improved from 0.79154 to 0.80441, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 0.9999 - loss: 0.0616 - val_accuracy: 0.8044 - val_loss: 1.0243 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0611
# Epoch 84: val_accuracy improved from 0.80441 to 0.81239, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 1.0000 - loss: 0.0611 - val_accuracy: 0.8124 - val_loss: 0.9893 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 85/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0602
# Epoch 85: val_accuracy improved from 0.81239 to 0.81729, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 1.0000 - loss: 0.0602 - val_accuracy: 0.8173 - val_loss: 0.9807 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 86/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9999 - loss: 0.0599
# Epoch 86: val_accuracy did not improve from 0.81729
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9999 - loss: 0.0599 - val_accuracy: 0.8161 - val_loss: 0.9716 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0591
# Epoch 87: val_accuracy did not improve from 0.81729
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 1.0000 - loss: 0.0591 - val_accuracy: 0.8161 - val_loss: 0.9651 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 88/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0585
# Epoch 88: val_accuracy did not improve from 0.81729
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 1.0000 - loss: 0.0585 - val_accuracy: 0.8155 - val_loss: 0.9682 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 89/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0578
# Epoch 89: val_accuracy did not improve from 0.81729
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 1.0000 - loss: 0.0578 - val_accuracy: 0.8167 - val_loss: 0.9577 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 90/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0574
# Epoch 90: val_accuracy improved from 0.81729 to 0.81790, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 337ms/step - accuracy: 1.0000 - loss: 0.0574 - val_accuracy: 0.8179 - val_loss: 0.9554 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 91/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0564
# Epoch 91: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 1.0000 - loss: 0.0564 - val_accuracy: 0.8173 - val_loss: 0.9521 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 92/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 1.0000 - loss: 0.0557
# Epoch 92: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 336ms/step - accuracy: 1.0000 - loss: 0.0557 - val_accuracy: 0.8167 - val_loss: 0.9529 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 93/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 1.0000 - loss: 0.0550
# Epoch 93: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 1.0000 - loss: 0.0550 - val_accuracy: 0.8142 - val_loss: 0.9744 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 94/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0540
# Epoch 94: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 1.0000 - loss: 0.0540 - val_accuracy: 0.8148 - val_loss: 0.9635 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 95/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9999 - loss: 0.0533
# Epoch 95: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9999 - loss: 0.0533 - val_accuracy: 0.8155 - val_loss: 0.9586 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 96/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9999 - loss: 0.0525
# Epoch 96: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 0.9999 - loss: 0.0525 - val_accuracy: 0.8112 - val_loss: 0.9560 - learning_rate: 3.1623e-05
# Learning rate:  0.0001
# Epoch 97/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0512
# Epoch 97: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 335ms/step - accuracy: 1.0000 - loss: 0.0512 - val_accuracy: 0.8161 - val_loss: 0.9397 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 98/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 1.0000 - loss: 0.0501
# Epoch 98: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 68s 336ms/step - accuracy: 1.0000 - loss: 0.0501 - val_accuracy: 0.8161 - val_loss: 0.9367 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 99/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 1.0000 - loss: 0.0490
# Epoch 99: val_accuracy did not improve from 0.81790
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 83s 339ms/step - accuracy: 1.0000 - loss: 0.0490 - val_accuracy: 0.8155 - val_loss: 0.9374 - learning_rate: 1.0000e-04
# Learning rate:  0.0001
# Epoch 100/100
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0479
# Epoch 100: val_accuracy improved from 0.81790 to 0.81913, saving model to /kaggle/working/saved_models/msi_ResNet20v1_model.keras
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 69s 336ms/step - accuracy: 1.0000 - loss: 0.0479 - val_accuracy: 0.8191 - val_loss: 0.9304 - learning_rate: 1.0000e-04

# %%
# Score trained model. 
scores = model.evaluate(X_test, y_test, verbose = 1) 
print('Test loss:', scores[0]) 
print('Test accuracy:', scores[1])
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8125 - loss: 0.9801
# Test loss: 0.9304448962211609
# Test accuracy: 0.8191293478012085
